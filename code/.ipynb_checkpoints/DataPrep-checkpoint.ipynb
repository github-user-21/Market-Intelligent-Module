# %%
# !pip install pyarrow fastparquet
# Out:
# Collecting pyarrow
#   Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting fastparquet
#   Downloading fastparquet-2025.12.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: pandas>=1.5.0 in ./venv/lib/python3.12/site-packages (from fastparquet) (2.3.3)
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (from fastparquet) (2.4.0)
# Collecting cramjam>=2.3 (from fastparquet)
#   Downloading cramjam-2.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting fsspec (from fastparquet)
#   Downloading fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in ./venv/lib/python3.12/site-packages (from fastparquet) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas>=1.5.0->fastparquet) (2025.3)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->fastparquet) (1.17.0)
# Downloading pyarrow-22.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (47.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 1.6 MB/s eta 0:00:0000:0100:01
# Downloading fastparquet-2025.12.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.4 MB/s eta 0:00:0000:0100:01m
# Downloading cramjam-2.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 6.0 MB/s eta 0:00:00:00:01
# Downloading fsspec-2025.12.0-py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 433.1 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyarrow, fsspec, cramjam, fastparquet
# Successfully installed cramjam-2.11.0 fastparquet-2025.12.0 fsspec-2025.12.0 pyarrow-22.0.0

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

pd.set_option("display.max_rows", 200)
pd.set_option("display.max_columns", 50)

# %%
engine = create_engine(
    "postgresql+psycopg2://market_predict:market_predict@localhost:5432/market_data"
)

# %%
spot_query = """
SELECT ts, open, high, low, close, volume
FROM ohlcv
WHERE symbol = 'BTCUSDT'
ORDER BY ts ASC
"""
spot_df = pd.read_sql(spot_query, engine)

# %%
spot_df
# Out:
#                             ts      open      high       low     close  \
# 0    2017-08-17 00:00:00+00:00   4261.48   4485.39   4200.74   4285.08
# 1    2017-08-18 00:00:00+00:00   4285.08   4371.52   3938.77   4108.37
# 2    2017-08-19 00:00:00+00:00   4108.37   4184.69   3850.00   4139.98
# 3    2017-08-20 00:00:00+00:00   4120.98   4211.08   4032.62   4086.29
# 4    2017-08-21 00:00:00+00:00   4069.13   4119.62   3911.79   4016.00
# ...                        ...       ...       ...       ...       ...
# 3052 2025-12-25 00:00:00+00:00  87669.44  88592.74  86934.72  87225.27
# 3053 2025-12-26 00:00:00+00:00  87225.27  89567.75  86655.08  87369.56
# 3054 2025-12-27 00:00:00+00:00  87369.56  87702.00  87253.05  87483.95
# 3055 2025-12-28 00:00:00+00:00  87877.00  88088.75  87435.00  87952.71
# 3056 2025-12-29 00:00:00+00:00  87952.71  90406.08  86806.50  87090.11
#
#             volume
# 0       795.150377
# 1      1199.888264
# 2       381.309763
# 3       467.083022
# 4       691.743060
# ...            ...
# 3052   7096.582350
# 3053  18344.615050
# 3054   2233.139970
# 3055   4446.292850
# 3056  13952.010380
#
# [3057 rows x 6 columns]

# %%
CUTOFF = pd.Timestamp("2025-01-29", tz="UTC")

spot_df = spot_df[spot_df["ts"] <= CUTOFF].copy()
unseen_df = spot_df[spot_df["ts"] > CUTOFF].copy()

# %%
# unseen_df = df[df["ts"] > pd.Timestamp("2025-12-29", tz="UTC")].copy()
unseen_df
# Out:
#                             ts       open       high        low      close  \
# 2904 2025-07-30 00:00:00+00:00  117950.75  118792.00  115796.23  117840.30
# 3010  36198.507710
# 3011  47288.144810
# 3012  15110.893910
# 3013  23889.405100
# 3014  39218.598060
# 3015  39835.147690
# 3016  32286.637600
# 3017  39733.190730
# 3018  72256.126790
# 3019  14193.932630
# 3020  19734.464180
# 3021  24663.127950
# 3022  19567.041100
# 3023  21675.822390
# 3024  16833.509320
# 3025  18830.860120
# 3026   7429.882910
# 3027   9687.741750
# 3028  34509.012270
# 3029  19702.501610
# 3030  25712.525850
# 3031  19803.940590
# 3032  19792.972180
# 3033   8409.500160
# 3034  13021.111850
# 3035  15793.638870
# 3036  21240.430140
# 3037  18998.680830
# 3038  19972.587580
# 3039  16679.191690
# 3040   5895.707880
# 3041   9416.940040
# 3042  19778.691900
# 3043  18456.050170
# 3044  19834.117290
# 3045  25405.417630
# 3046  21256.650040
# 3047   5123.131940
# 3048   7132.872580
# 3049  14673.219700
# 3050  13910.329040
# 3051   9140.843200
# 3052   7096.582350
# 3053  18344.615050
# 3054   2233.139970
# 3055   4446.292850
# 3056  13952.010380

# %%
spot_df['ts'] = pd.to_datetime(spot_df['ts'], utc=True)
spot_df = spot_df.sort_values('ts').reset_index(drop=True)

assert spot_df['ts'].is_monotonic_increasing
assert spot_df.duplicated(subset=['ts']).sum() == 0

spot_df.head(), spot_df.tail()
# Out:
# (                         ts     open     high      low    close       volume
#  0 2017-08-17 00:00:00+00:00  4261.48  4485.39  4200.74  4285.08   795.150377
#  1 2017-08-18 00:00:00+00:00  4285.08  4371.52  3938.77  4108.37  1199.888264
#  2 2017-08-19 00:00:00+00:00  4108.37  4184.69  3850.00  4139.98   381.309763
#  3 2017-08-20 00:00:00+00:00  4120.98  4211.08  4032.62  4086.29   467.083022
#  4 2017-08-21 00:00:00+00:00  4069.13  4119.62  3911.79  4016.00   691.743060,
#                              ts      open      high       low     close  \
#  3052 2025-12-25 00:00:00+00:00  87669.44  88592.74  86934.72  87225.27
#  3053 2025-12-26 00:00:00+00:00  87225.27  89567.75  86655.08  87369.56
#  3054 2025-12-27 00:00:00+00:00  87369.56  87702.00  87253.05  87483.95
#  3055 2025-12-28 00:00:00+00:00  87877.00  88088.75  87435.00  87952.71
#  3056 2025-12-29 00:00:00+00:00  87952.71  90406.08  86806.50  87090.11
#
#             volume
#  3052   7096.58235
#  3053  18344.61505
#  3054   2233.13997
#  3055   4446.29285
#  3056  13952.01038  )

# %%
today_utc = pd.Timestamp.utcnow().normalize()
if spot_df['ts'].iloc[-1] >= today_utc:
    spot_df = spot_df.iloc[:-1].reset_index(drop=True)

# %%
spot_df['log_return'] = np.log(
    spot_df['close'] / spot_df['close'].shift(1)
)
spot_df = spot_df.dropna(subset=['log_return']).reset_index(drop=True)

# %%
train_end = pd.Timestamp("2020-01-01", tz="UTC")
val_end   = pd.Timestamp("2023-01-01", tz="UTC")

def assign_split(ts):
    if ts < train_end:
        return "train"
    elif ts < val_end:
        return "val"
    else:
        return "test"

spot_df["split"] = spot_df["ts"].apply(assign_split)
spot_df["split"].value_counts()
# Out:
# split
# val      1096
# test     1094
# train     866
# Name: count, dtype: int64

# %%
train_returns = spot_df.loc[
    spot_df["split"] == "train", "log_return"
]

q10 = train_returns.quantile(0.10)
q30 = train_returns.quantile(0.30)
q70 = train_returns.quantile(0.70)
q90 = train_returns.quantile(0.90)

q10, q30, q70, q90
# Out:
# (np.float64(-0.04800776698705181),
#  np.float64(-0.011619451004109261),
#  np.float64(0.014258320311006007),
#  np.float64(0.04752814313655959))

# %%
def assign_regime(r):
    if r <= q10:
        return 0
    elif r <= q30:
        return 1
    elif r <= q70:
        return 2
    elif r <= q90:
        return 3
    else:
        return 4

spot_df["regime"] = spot_df["log_return"].apply(assign_regime)

spot_df.groupby(["split", "regime"]).size().unstack()
# Out:
# regime   0    1    2    3   4
# split
# test    32  218  595  210  39
# train   87  173  346  173  87
# val     81  241  449  242  83

# %%
spot_out = spot_df[[
    "ts",
    "open", "high", "low", "close", "volume",
    "log_return",
    "regime",
    "split"
]]

from pathlib import Path

Path("data").mkdir(parents=True, exist_ok=True)

spot_out.to_parquet(
    "data/module1_spot_v0.parquet",
    index=False)

# %%
oi_query = """
SELECT ts, symbol, open_interest
FROM open_interest
WHERE symbol = 'BTCUSDT'
ORDER BY ts ASC
"""
oi_df = pd.read_sql(oi_query, engine)

# %%
oi_df['ts'] = pd.to_datetime(oi_df['ts'], utc=True)
oi_df = (
    oi_df
    .drop_duplicates(subset=['symbol','ts'], keep='last')
    .sort_values('ts')
    .reset_index(drop=True)
)

# %%
calendar = spot_out[['ts']].copy()

oi_aligned = calendar.merge(
    oi_df[['ts','open_interest']],
    on='ts',
    how='left'
)

oi_aligned['oi_change'] = (
    oi_aligned['open_interest'] -
    oi_aligned['open_interest'].shift(1)
)

# %%
oi_aligned.to_parquet(
    "data/module1_open_interest_v0.parquet",
    index=False
)

# %%
funding_query = """
SELECT ts, symbol, funding_rate
FROM funding_rates
WHERE symbol = 'BTCUSDT'
ORDER BY ts ASC
"""
funding_df = pd.read_sql(funding_query, engine)

# %%
funding_df['ts'] = pd.to_datetime(funding_df['ts'], utc=True)

funding_daily = (
    funding_df
    .groupby([
        funding_df['ts'].dt.normalize()
    ])
    .agg({"funding_rate": "mean"})
    .reset_index()
    .rename(columns={"ts": "ts"})
)

funding_aligned = calendar.merge(
    funding_daily,
    on='ts',
    how='left'
)

# %%
funding_aligned.to_parquet(
    "data/module1_funding_v0.parquet",
    index=False
)

# %%
futures_query = """
SELECT ts, open, high, low, close, volume
FROM futures_ohlcv
WHERE symbol = 'BTCUSDT'
ORDER BY ts ASC
"""
futures_df = pd.read_sql(futures_query, engine)

# %%
futures_df['ts'] = pd.to_datetime(futures_df['ts'], utc=True)
futures_df = (
    futures_df
    .drop_duplicates(subset=['ts'], keep='last')
    .sort_values('ts')
    .reset_index(drop=True)
)

futures_df.to_parquet(
    "data/module1_futures_ohlcv_v0.parquet",
    index=False
)

# %%
unseen_df.to_parquet("data/unseen_data.parquet",index=False)
